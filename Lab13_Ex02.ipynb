// %% [markdown]
// # Lab 13 Exercise 2

// %% [markdown]
// ## Constructors

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab13_Ex02
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var circle = new Circle();
// var rectangle = new Rectangle();
// var triangle = new Triangle();
//
// class Shape
// {
//     public Shape()
//     {
//         System.Console.WriteLine("This is some shape");
//     }
// }
// class Circle :Shape
// {
//     public Circle()
//     {
//         System.Console.WriteLine("This is a circle");
//     }
// }
// class Rectangle :Shape
// {
//     public Rectangle()
//     {
//         System.Console.WriteLine("This is a rectangle");
//     }
// }
// class Triangle :Shape
// {
//    public Triangle()
//     {
//         System.Console.WriteLine("This is a triangle");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab13_Ex02
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![03.png](attachment:03.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab13_Ex02
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![04.png](attachment:04.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ในการทดลองนี้มีการสร้างออบเจ็กต์ Circle, Rectangle, และ Triangle คอนสตรักเตอร์ของ Shape ซึ่งจะทำงานก่อนเสมอ เพราะคลาสเหล่านี้สืบทอดจาก Shape
