// %% [markdown]
// # Lab 13 Exercise 1

// %% [markdown]
// ## Constructors

// %% [markdown]
// Constructor เป็นเมธอดพิเศษในคลาสที่ถูกเรียกใช้โดยอัตโนมัติเมื่อสร้างอ็อบเจ็กต์ใหม่ของคลาสนั้นๆ หน้าที่หลักของ constructor คือการเริ่มต้นสถานะของอ็อบเจ็กต์ เช่น กำหนดค่าเริ่มต้นให้กับตัวแปรสมาชิก (member variables)

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab13_Ex01
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var shape = new Shape();
// var circle = new Circle();
// var rectangle = new Rectangle();
// var triangle = new Triangle();
//
// class Shape
// {
//     public Shape()
//     {
//         System.Console.WriteLine("This is some shape");
//     }
// }
// class Circle
// {
//     public Circle()
//     {
//         System.Console.WriteLine("This is a circle");
//     }
// }
// class Rectangle
// {
//     public Rectangle()
//     {
//         System.Console.WriteLine("This is a rectangle");
//     }
// }
// class Triangle
// {
//    public Triangle()
//     {
//         System.Console.WriteLine("This is a triangle");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab13_Ex01
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![01.png](attachment:01.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab13_Ex01
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![02.png](attachment:02.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// โค้ดในการทดลองนี้ไม่มีการสืบทอด (inheritance) ซึ่งหมายความว่า Circle, Rectangle, Triangle ไม่เกี่ยวข้องกับ Shape
